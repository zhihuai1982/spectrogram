# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df = pd.read_csv('10069_15268.tsv', sep='\t')

# %%
df
# Out:
#              onset   duration  \
# 0         0.746094   0.000000
# 1         0.746094   0.000000
# 2         0.746094   0.000000
# 3         0.750000   0.000000
# 4         0.750000   0.000000
# 5         3.562500   0.000000
# 6      3068.832031   0.000000
# 7      3110.882812   0.000000
# 8      4255.035156   0.000000
# 9      4283.718750   0.000000
# 10     4299.671875   0.000000
# 11     4306.785156   0.000000
# 12     4317.550781   0.000000
# 13     4334.679688   0.000000
# 14     4348.039062   0.000000
# 15     4352.757812   0.000000
# 16     4352.953125   0.000000
# 17     4357.078125   0.000000
# 18     4360.691406   0.000000
# 19     4361.714844   0.000000
# 20     4376.683594   0.000000
# 21     4382.972656   0.000000
# 22     4408.707031   0.000000
# 23     4429.335938   0.000000
# 24     4447.097656   0.000000
# 25     4465.996094   0.000000
# 26     4472.757812   0.000000
# 27     5730.710938  30.000000
# 28     5748.472656   0.000000
# 29     5751.515625   0.000000
# ...

# %%
df.loc[df['description'].str.contains('Breath')]
# Out:
#           onset  duration      description
# 22  4408.707031       0.0  Nasal Breathing
# 23  4429.335938       0.0   Oral Breathing
# 24  4447.097656       0.0      Hold Breath
